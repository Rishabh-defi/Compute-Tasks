# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishabh-defi/Compute-Tasks/blob/main/ML_Task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as ss
import seaborn as sns

# %%
df_countries = pd.read_csv(r"/content/Country.csv")
df_leagues = pd.read_csv(r"/content/League.csv")
df_matches = pd.read_csv(r"/content/matches.csv")
df_teams=pd.read_csv(r"/content/Team.csv")
df_TeamAttributes=pd.read_csv(r"/content/Team_Attributes.csv")

# %%
df_matches['Country_name'] = df_matches['country_id'].map(df_leagues.set_index('country_id')['name.1'].drop_duplicates())  
df_matches
# Out:
#        Unnamed: 0     id  country_id  league_id     season  stage  \
# 0               0      1           1          1  2008/2009      1
# 1               1      2           1          1  2008/2009      1
# 2               2      3           1          1  2008/2009      1
# 3               3      4           1          1  2008/2009      1
# 4               4      5           1          1  2008/2009      1
# ...           ...    ...         ...        ...        ...    ...
# 24528       24528  24529       21518      21518  2015/2016      7
# 24529       24529  24530       21518      21518  2015/2016      7
# 24530       24530  24531       21518      21518  2015/2016      7
# 24531       24531  24532       21518      21518  2015/2016      7
# 24532       24532  24533       21518      21518  2015/2016      7
#
#                       date  match_api_id  home_team_api_id  away_team_api_id  \
# 0      2008-08-17 00:00:00        492473              9987              9993
# 1      2008-08-16 00:00:00        492474             10000              9994
# 2      2008-08-16 00:00:00        492475              9984              8635
# 3      2008-08-17 00:00:00        492476              9991              9998
# 4      2008-08-16 00:00:00        492477              7947              9985
# ...                    ...           ...               ...               ...
# 24528  2015-10-03 00:00:00       2030143              8306              8372
# 24529  2015-10-02 00:00:00       2030144              9910              8305
# 24530  2015-10-04 00:00:00       2030145              8581             10205
# 24531  2015-10-04 00:00:00       2030146              9906              8633
# 24532  2015-10-03 00:00:00       2030147              9864              8560
#
#        ...   VCH   VCD   VCA   GBH   GBD   GBA   BSH   BSD   BSA  Country_name
# 0      ...  1.65  3.40  4.50  1.78  3.25  4.00  1.73  3.40  4.20      Belgium
# 1      ...  2.00  3.25  3.25  1.85  3.25  3.75  1.91  3.25  3.60      Belgium
# 2      ...  2.35  3.25  2.65  2.50  3.20  2.50  2.30  3.20  2.75      Belgium
# 3      ...  1.45  3.75  6.50  1.50  3.75  5.50  1.44  3.75  6.50      Belgium
# 4      ...  4.50  3.40  1.65  4.50  3.50  1.65  4.75  3.30  1.67      Belgium
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...           ...
# 24528  ...  2.05  3.40  4.10   NaN   NaN   NaN   NaN   NaN   NaN         Spain
# 24529  ...  1.50  4.50  7.50   NaN   NaN   NaN   NaN   NaN   NaN         Spain
# 24530  ...  4.40  3.60  1.93   NaN   NaN   NaN   NaN   NaN   NaN         Spain
# 24531  ...  3.13  3.40  2.45   NaN   NaN   NaN   NaN   NaN   NaN         Spain
# 24532  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN         Spain
#
# [24533 rows x 117 columns]

# %%
df_matches['League_name'] = df_matches['country_id'].map(df_leagues.set_index('country_id')['name'].drop_duplicates())

# %%
df_matches['Home_team_name'] = df_matches['home_team_api_id'].map(df_teams.set_index('team_api_id')['team_long_name'].drop_duplicates())

# %%
df_matches['Away_team_name'] = df_matches['away_team_api_id'].map(df_teams.set_index('team_api_id')['team_long_name'].drop_duplicates())

# %%
df_dataframe = df_matches.groupby(['Country_name'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-85-5a9340af0ba5> in <module>
# ----> 1 df_dataframe = df_matches.groupby(['Country_name'])
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7629         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7630         # "Union[bool, NoDefault]"; expected "bool"
# -> 7631         return DataFrameGroupBy(
#    7632             obj=self,
#    7633             keys=by,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     887             from pandas.core.groupby.grouper import get_grouper
#     888
# --> 889             grouper, exclusions, obj = get_grouper(
#     890                 obj,
#     891                 keys,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     860                 in_axis, level, gpr = False, gpr, None
#     861             else:
# --> 862                 raise KeyError(gpr)
#     863         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     864             # Add key to exclusions
#
# KeyError: 'Country_name'

# %%
plt.figure(figsize=(30,20))
sns.barplot(x='Country_name',y='home_team_goal',data=df_matches)

# %%
plt.figure(figsize=(30,20))
sns.barplot(x='Country_name',y='away_team_goal',data=df_matches)

# %%
df_TeamAttributes['team_name'] = df_TeamAttributes['team_api_id'].map(df_teams.set_index('team_api_id')['team_long_name'].drop_duplicates())
df_TeamAttributes
# Out:
#      id  team_fifa_api_id  team_api_id                 date  buildUpPlaySpeed  \
# 0     1               434         9930  2010-02-22 00:00:00                60
# 1     2               434         9930  2014-09-19 00:00:00                52
# 2     3               434         9930  2015-09-10 00:00:00                47
# 3     4                77         8485  2010-02-22 00:00:00                70
# 4     5                77         8485  2011-02-22 00:00:00                47
# ..  ...               ...          ...                  ...               ...
# 95   96               240         9906  2011-02-22 00:00:00                57
# 96   97               240         9906  2012-02-22 00:00:00                47
# 97   98               240         9906  2013-09-20 00:00:00                47
# 98   99               240         9906  2014-09-19 00:00:00                47
# 99  100               240         9906  2015-09-10 00:00:00                57
#
#    buildUpPlaySpeedClass  buildUpPlayDribbling buildUpPlayDribblingClass  \
# 0               Balanced                   NaN                    Little
# 1               Balanced                  48.0                    Normal
# 2               Balanced                  41.0                    Normal
# 3                   Fast                   NaN                    Little
# 4               Balanced                   NaN                    Little
# ..                   ...                   ...                       ...
# 95              Balanced                   NaN                    Little
# 96              Balanced                   NaN                    Little
# 97              Balanced                   NaN                    Little
# 98              Balanced                  52.0                    Normal
# 99              Balanced                  50.0                    Normal
#
#     buildUpPlayPassing buildUpPlayPassingClass  ... defencePressure  \
# 0                   50                   Mixed  ...              50
# 1                   56                   Mixed  ...              47
# 2                   54                   Mixed  ...              47
# 3                   70                    Long  ...              60
# 4                   52                   Mixed  ...              47
# ..                 ...                     ...  ...             ...
# 95                  54                   Mixed  ...              58
# 96                  51                   Mixed  ...              52
# 97                  51                   Mixed  ...              52
# 98                  51                   Mixed  ...              52
# 99                  50                   Mixed  ...              49
#
#     defencePressureClass defenceAggression  defenceAggressionClass  \
# 0                 Medium                55                   Press
# 1                 Medium                44                   Press
# 2                 Medium                44                   Press
# 3                 Medium                70                  Double
# 4                 Medium                47                   Press
# ..                   ...               ...                     ...
# 95                Medium                48                   Press
# 96                Medium                37                   Press
# 97                Medium                37                   Press
# 98                Medium                37                   Press
# 99                Medium                42                   Press
#
#    defenceTeamWidth  defenceTeamWidthClass defenceDefenderLineClass team_name  \
# 0                45                 Normal                    Cover       NaN
# 1                54                 Normal                    Cover       NaN
# 2                54                 Normal                    Cover       NaN
# 3                70                   Wide                    Cover       NaN
# 4                52                 Normal                    Cover       NaN
# ..              ...                    ...                      ...       ...
# 95               54                 Normal                    Cover       NaN
# 96               55                 Normal                    Cover       NaN
# 97               55                 Normal                    Cover       NaN
# 98               55                 Normal                    Cover       NaN
# 99               52                 Normal                    Cover       NaN
#
#     country home_goals
# 0       NaN        NaN
# 1       NaN        NaN
# 2       NaN        NaN
# 3       NaN        NaN
# 4       NaN        NaN
# ..      ...        ...
# 95      NaN        NaN
# 96      NaN        NaN
# 97      NaN        NaN
# 98      NaN        NaN
# 99      NaN        NaN
#
# [100 rows x 28 columns]

# %%
df_matches['Country_name'] = df_matches['country_id'].map(df_leagues.set_index('country_id')['name.1'].drop_duplicates()) 
df_TeamAttributes['country'] = df_TeamAttributes['team_api_id'].map(df_matches.set_index('home_team_api_id')['Country_name'].drop_duplicates())
df_TeamAttributes
# Out:
#      id  team_fifa_api_id  team_api_id                 date  buildUpPlaySpeed  \
# 0     1               434         9930  2010-02-22 00:00:00                60
# 1     2               434         9930  2014-09-19 00:00:00                52
# 2     3               434         9930  2015-09-10 00:00:00                47
# 3     4                77         8485  2010-02-22 00:00:00                70
# 4     5                77         8485  2011-02-22 00:00:00                47
# ..  ...               ...          ...                  ...               ...
# 95   96               240         9906  2011-02-22 00:00:00                57
# 96   97               240         9906  2012-02-22 00:00:00                47
# 97   98               240         9906  2013-09-20 00:00:00                47
# 98   99               240         9906  2014-09-19 00:00:00                47
# 99  100               240         9906  2015-09-10 00:00:00                57
#
#    buildUpPlaySpeedClass  buildUpPlayDribbling buildUpPlayDribblingClass  \
# 0               Balanced                   NaN                    Little
# 1               Balanced                  48.0                    Normal
# 2               Balanced                  41.0                    Normal
# 3                   Fast                   NaN                    Little
# 4               Balanced                   NaN                    Little
# ..                   ...                   ...                       ...
# 95              Balanced                   NaN                    Little
# 96              Balanced                   NaN                    Little
# 97              Balanced                   NaN                    Little
# 98              Balanced                  52.0                    Normal
# 99              Balanced                  50.0                    Normal
#
#     buildUpPlayPassing buildUpPlayPassingClass  ... defencePressure  \
# 0                   50                   Mixed  ...              50
# 1                   56                   Mixed  ...              47
# 2                   54                   Mixed  ...              47
# 3                   70                    Long  ...              60
# 4                   52                   Mixed  ...              47
# ..                 ...                     ...  ...             ...
# 95                  54                   Mixed  ...              58
# 96                  51                   Mixed  ...              52
# 97                  51                   Mixed  ...              52
# 98                  51                   Mixed  ...              52
# 99                  50                   Mixed  ...              49
#
#     defencePressureClass defenceAggression  defenceAggressionClass  \
# 0                 Medium                55                   Press
# 1                 Medium                44                   Press
# 2                 Medium                44                   Press
# 3                 Medium                70                  Double
# 4                 Medium                47                   Press
# ..                   ...               ...                     ...
# 95                Medium                48                   Press
# 96                Medium                37                   Press
# 97                Medium                37                   Press
# 98                Medium                37                   Press
# 99                Medium                42                   Press
#
#    defenceTeamWidth  defenceTeamWidthClass defenceDefenderLineClass team_name  \
# 0                45                 Normal                    Cover       NaN
# 1                54                 Normal                    Cover       NaN
# 2                54                 Normal                    Cover       NaN
# 3                70                   Wide                    Cover       NaN
# 4                52                 Normal                    Cover       NaN
# ..              ...                    ...                      ...       ...
# 95               54                 Normal                    Cover       NaN
# 96               55                 Normal                    Cover       NaN
# 97               55                 Normal                    Cover       NaN
# 98               55                 Normal                    Cover       NaN
# 99               52                 Normal                    Cover       NaN
#
#     country home_goals
# 0       NaN        NaN
# 1       NaN        NaN
# 2       NaN        NaN
# 3       NaN        NaN
# 4       NaN        NaN
# ..      ...        ...
# 95      NaN        NaN
# 96      NaN        NaN
# 97      NaN        NaN
# 98      NaN        NaN
# 99      NaN        NaN
#
# [100 rows x 28 columns]

# %%
df_matches['Home_team_name'] = df_matches['home_team_api_id'].map(df_teams.set_index('team_api_id')['team_long_name'].drop_duplicates())
df_vizz_teams=df_matches.groupby(['Home_team_name'])
df_vizz_teams=df_vizz_teams.first()
df_vizz_teams
# Out:
#                           Unnamed: 0    id  country_id  league_id     season  \
# Home_team_name
# AC Ajaccio                      5908  5909        4769       4769  2011/2012
# AC Arles-Avignon                5538  5539        4769       4769  2010/2011
# AJ Auxerre                      4768  4769        4769       4769  2008/2009
# AS Monaco                       4773  4774        4769       4769  2008/2009
# AS Nancy-Lorraine               4774  4775        4769       4769  2008/2009
# ...                              ...   ...         ...        ...        ...
# West Bromwich Albion            1754  1755        1729       1729  2008/2009
# West Ham United                 1731  1732        1729       1729  2008/2009
# Wigan Athletic                  1767  1768        1729       1729  2008/2009
# Wolverhampton Wanderers         2112  2113        1729       1729  2009/2010
# Évian Thonon Gaillard FC        5921  5922        4769       4769  2011/2012
#
#                           stage                 date  match_api_id  \
# Home_team_name
# AC Ajaccio                    1  2011-08-06 00:00:00       1019336
# AC Arles-Avignon             10  2010-10-24 00:00:00        829964
# AJ Auxerre                    1  2008-08-09 00:00:00        483129
# AS Monaco                     1  2008-08-09 00:00:00        483134
# AS Nancy-Lorraine             1  2008-08-09 00:00:00        483135
# ...                         ...                  ...           ...
# West Bromwich Albion         11  2008-11-01 00:00:00        489148
# West Ham United               1  2008-08-16 00:00:00        489045
# Wigan Athletic               12  2008-11-08 00:00:00        489161
# Wolverhampton Wanderers       1  2009-08-15 00:00:00        658577
# Évian Thonon Gaillard FC     10  2011-10-15 00:00:00       1019507
#
#                           home_team_api_id  away_team_api_id  ...   VCH   VCD  \
# Home_team_name                                                ...
# AC Ajaccio                            8576              9941  ...  2.63  3.10
# AC Arles-Avignon                    108893              9748  ...  7.50  4.00
# AJ Auxerre                            8583              9830  ...  2.00  2.90
# AS Monaco                             9829              9847  ...  2.25  3.00
# AS Nancy-Lorraine                     8481              8639  ...  2.10  3.00
# ...                                    ...               ...  ...   ...   ...
# West Bromwich Albion                  8659              8655  ...  2.55  3.35
# West Ham United                       8654              8528  ...  1.90  3.50
# Wigan Athletic                        8528             10194  ...  1.75  3.40
# Wolverhampton Wanderers               8602              8654  ...  2.50  3.25
# Évian Thonon Gaillard FC              4087              9853  ...  2.50  3.10
#
#                            VCA   GBH   GBD   GBA   BSH   BSD   BSA  \
# Home_team_name
# AC Ajaccio                3.00  2.50  3.00  2.80  2.60  3.00  2.75
# AC Arles-Avignon          1.53  6.25  3.50  1.55  6.50  3.60  1.53
# AJ Auxerre                3.75  2.10  3.00  3.75  2.00  2.88  3.75
# AS Monaco                 3.00  2.38  3.00  3.00  2.30  3.00  2.88
# AS Nancy-Lorraine         3.30  2.20  3.00  3.30  2.00  3.00  3.60
# ...                        ...   ...   ...   ...   ...   ...   ...
# West Bromwich Albion      2.80  2.50  3.30  2.75  2.50  3.20  2.70
# West Ham United           4.35  1.91  3.25  4.00  1.91  3.25  3.80
# Wigan Athletic            5.00  1.80  3.30  4.75  1.83  3.30  4.50
# Wolverhampton Wanderers   2.62  2.50  3.20  2.75  2.50  3.25  2.70
# Évian Thonon Gaillard FC  3.12  2.40  3.10  3.00  2.40  3.10  3.00
#
#                           Country_name
# Home_team_name
# AC Ajaccio                      France
# AC Arles-Avignon                France
# AJ Auxerre                      France
# AS Monaco                       France
# AS Nancy-Lorraine               France
# ...                                ...
# West Bromwich Albion           England
# West Ham United                England
# Wigan Athletic                 England
# Wolverhampton Wanderers        England
# Évian Thonon Gaillard FC        France
#
# [99 rows x 117 columns]

# %%
df_vizz_s=df_TeamAttributes.groupby(['country'])
df_vizz_s=df_vizz_s.first()

# %%
plt.figure(figsize=(20,20))
sns.catplot(x='team_name',y='buildUpPlaySpeedClass',data=df_vizz_s) 
plt.xticks(rotation = 90) 
plt.figure(figsize=(20,20))
sns.catplot(x='team_name',y='buildUpPlayPassingClass',data=df_vizz_s)  
plt.xticks(rotation = 90)
# Out:
# (array([9.40e+19, 9.60e+19, 9.80e+19, 1.00e+20, 1.02e+20, 1.04e+20,
#         1.06e+20]), <a list of 7 Text major ticklabel objects>)

# %%
df_TeamAttributes['home_goals'] = df_TeamAttributes['team_api_id'].map(df_matches.set_index('home_team_api_id')['home_team_goal'].drop_duplicates()) 
sns.barplot(x='home_goals',y='buildUpPlaySpeedClass',palette='Set2',data=df_TeamAttributes)

# %%
sns.barplot(x='home_goals',y='buildUpPlayPassingClass',palette='Set2',data=df_TeamAttributes)

# %%
df_vizz_bu=df_TeamAttributes.groupby(['buildUpPlayPassingClass','buildUpPlaySpeedClass']) 
df_vizz_bu=df_vizz_bu.first()

# %%
fig, ax = plt.subplots(figsize=(15,7))
df_vizz_bu=df_TeamAttributes.groupby(['buildUpPlayPassingClass','buildUpPlaySpeedClass']).count()['home_goals'].plot(ax=ax)

# %%
#1. Does Aggression, Long Shots, Shot power correlate to each other?
#2. Does Vision, GK reflexes, GK Handling depend upon each other?
#3. Does Ball Control relate to Balance?

# %%
df_PA= pd.read_csv(r"/content/Player_Attributes.csv")

# %%
sns.lineplot(data =df_PA,x = "shot_power", y = "long_shots")

# %%
sns.lineplot(data =df_PA,x = "aggression", y = "long_shots")

# %%
sns.lineplot(data =df_PA,x = "aggression", y = "shot_power")

# %%
#hence we can say that there is no perfect correlationship between shot power, aggresion and long shots.

# %%
sns.lineplot(data =df_PA,x = "vision", y = "gk_reflexes")

# %%
sns.lineplot(data =df_PA,x = "vision", y = "gk_handling")

# %%
sns.lineplot(data =df_PA,x = "gk_reflexes", y = "gk_handling")

# %%
#hence we can say that gk_handling is very positively correlated to gk_reflexes.

# %%
sns.lineplot(data =df_PA,x = "balance", y = "ball_control")

# %%
#after 60 as balance increases ball control increases before that we can't see any correlation.
